# %% [markdown]
# <a href="https://colab.research.google.com/github/missmaithya/Assignment/blob/Project/Lecture3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dictionary= {
    "Key1": "value1",
    "Key2": "value2",
    "Key3": "value3",
    "Key4": "value4",
    "Key5": 34
}

print(dictionary)
print(dictionary["Key1"])
print(dictionary["Key2"])
print(dictionary["Key3"])
print(dictionary["Key4"])
print(dictionary["Key5"])

car = {
    "brand":"ford",
    "model":"mustang",
    "year":2020

}
car["color"]='red'
print(car)
